# %%
import os
import json
import pandas as pd
import mysql.connector
import streamlit as st

# %%
#aggregate_transaction

path1= "C:/Users/sujit/vs inside/Phonepe/pulse/data/aggregated/transaction/country/india/state/"
agg_tran_list=os.listdir(path1)


columns1={"States":[],"Years":[],"Quarter":[],"Transaction_type":[],"Transaction_count":[],"Transaction_amount":[]}
for state in agg_tran_list:
    cur_states = path1+state+"/"
    agg_year_list=os.listdir(cur_states)
    
    for year in agg_year_list:
        cur_year= cur_states+year+"/"
        agg_file_list = os.listdir(cur_year)
        
        for file in agg_file_list:
            cur_file = cur_year+file
            data=open(cur_file,"r")
            
            A=json.load(data)
            for i in A["data"]["transactionData"]:
                name=i["name"]
                count=i["paymentInstruments"][0]["count"]
                amount=i["paymentInstruments"][0]["amount"]
                columns1["Transaction_type"].append(name)
                columns1["Transaction_count"].append(count)
                columns1["Transaction_amount"].append(amount)
                columns1["States"].append(state)
                columns1["Years"].append(year)
                columns1["Quarter"].append(int(file.strip("j.son")))

# %%
agg_tran = pd.DataFrame(columns1)

# %%
agg_tran
# Out:
#                          States Years  Quarter          Transaction_type  \
# 0     andaman-&-nicobar-islands  2018        1  Recharge & bill payments
# 1     andaman-&-nicobar-islands  2018        1     Peer-to-peer payments
# 2     andaman-&-nicobar-islands  2018        1         Merchant payments
# 3     andaman-&-nicobar-islands  2018        1        Financial Services
# 4     andaman-&-nicobar-islands  2018        1                    Others
# ...                         ...   ...      ...                       ...
# 4129                west-bengal  2023        3         Merchant payments
# 4130                west-bengal  2023        3     Peer-to-peer payments
# 4131                west-bengal  2023        3  Recharge & bill payments
# 4132                west-bengal  2023        3        Financial Services
# 4133                west-bengal  2023        3                    Others
#
#       Transaction_count  Transaction_amount
# 0                  4200        1.845307e+06
# ...

# %%
#aggre_user

path2="C:/Users/sujit/vs inside/Phonepe/pulse/data/aggregated/user/country/india/state/"
agg_user_list=os.listdir(path2)


columns2={"States":[],"Years":[],"Quarter":[],"Brands":[],"Transaction_count":[],"Percentage":[]}
for state in agg_user_list:
    cur_states = path2+state+"/"
    agg_year_list=os.listdir(cur_states)
    
    for year in agg_year_list:
        cur_year= cur_states+year+"/"
        agg_file_list = os.listdir(cur_year)
        
        for file in agg_file_list:
            cur_file = cur_year+file
            data=open(cur_file,"r")
            
            B=json.load(data)
            try:
                for i in B["data"]["usersByDevice"]:
                    brand=i["brand"]
                    count=i["count"]
                    percentage=i["percentage"]
                    columns2["Brands"].append(brand)
                    columns2["Transaction_count"].append(count)
                    columns2["Percentage"].append(percentage)
                    columns2["States"].append(state)
                    columns2["Years"].append(year)
                    columns2["Quarter"].append(int(file.strip("j.son")))
                    
            except:
                pass

# %%
aggre_user = pd.DataFrame(columns2)

# %%
aggre_user
# Out:
#                          States Years  Quarter   Brands  Transaction_count  \
# 0     andaman-&-nicobar-islands  2018        1   Xiaomi               1665
# 1     andaman-&-nicobar-islands  2018        1  Samsung               1445
# 2     andaman-&-nicobar-islands  2018        1     Vivo                982
# 3     andaman-&-nicobar-islands  2018        1     Oppo                501
# 4     andaman-&-nicobar-islands  2018        1  OnePlus                332
# ...                         ...   ...      ...      ...                ...
# 6727                west-bengal  2022        1   Lenovo             330017
# 6728                west-bengal  2022        1  Infinix             284678
# 6729                west-bengal  2022        1     Asus             280347
# 6730                west-bengal  2022        1    Apple             277752
# 6731                west-bengal  2022        1   Others            2196334
#
#       Percentage
# 0       0.247033
# 1       0.214392
# ...

# %%
path3="C:/Users/sujit/vs inside/Phonepe/pulse/data/map/transaction/hover/country/india/state/"
map_tran_list=os.listdir(path3)

columns3={"States":[],"Years":[],"Quarter":[],"Districts":[],"Transaction_count":[],"Transaction_amount":[]}
for state in map_tran_list:
    cur_states = path3+state+"/"
    agg_year_list=os.listdir(cur_states)
    
    for year in agg_year_list:
        cur_year= cur_states+year+"/"
        agg_file_list = os.listdir(cur_year)
        
        for file in agg_file_list:
            cur_file = cur_year+file
            data=open(cur_file,"r")
            
            C=json.load(data)
            for i in C["data"]["hoverDataList"]:
                    name=i["name"]
                    count=i["metric"][0]["count"]
                    amount=i["metric"][0]["amount"]
                    columns3["Districts"].append(name)
                    columns3["Transaction_count"].append(count)
                    columns3["Transaction_amount"].append(amount)
                    columns3["States"].append(state)
                    columns3["Years"].append(year)
                    columns3["Quarter"].append(int(file.strip("j.son")))

# %%
map_tran=pd.DataFrame(columns3)

# %%
map_tran
# Out:
#                           States Years  Quarter  \
# 0      andaman-&-nicobar-islands  2018        1
# 1      andaman-&-nicobar-islands  2018        1
# 2      andaman-&-nicobar-islands  2018        1
# 3      andaman-&-nicobar-islands  2018        2
# 4      andaman-&-nicobar-islands  2018        2
# ...                          ...   ...      ...
# 16827                west-bengal  2023        3
# 16828                west-bengal  2023        3
# 16829                west-bengal  2023        3
# 16830                west-bengal  2023        3
# 16831                west-bengal  2023        3
#
#                                Districts  Transaction_count  \
# 0      north and middle andaman district                442
# 1                 south andaman district               5688
# 2                      nicobars district                528
# 3      north and middle andaman district                825
# 4                 south andaman district               9395
# ...

# %%
#map_user
path4="C:/Users/sujit/vs inside/Phonepe/pulse/data/map/user/hover/country/india/state/"
map_user_list=os.listdir(path4)

columns4={"States":[],"Years":[],"Quarter":[],"Districts":[],"RegisteredUsers":[],"AppOpens":[]}
for state in map_user_list:
    cur_states = path4+state+"/"
    agg_year_list=os.listdir(cur_states)
    
    for year in agg_year_list:
        cur_year= cur_states+year+"/"
        agg_file_list = os.listdir(cur_year)
        
        for file in agg_file_list:
            cur_file = cur_year+file
            data=open(cur_file,"r")
            
            D=json.load(data)
            for i in D["data"]["hoverData"].items():
                district=i[0]
                registeredUsers=i[1]["registeredUsers"]
                appOpens=i[1]["appOpens"]
                columns4["Districts"].append(district)
                columns4["RegisteredUsers"].append(registeredUsers)
                columns4["AppOpens"].append(appOpens)
                columns4["States"].append(state)
                columns4["Years"].append(year)
                columns4["Quarter"].append(int(file.strip("j.son")))

# %%
map_user = pd.DataFrame(columns4)

# %%
map_user
# Out:
#                           States Years  Quarter  \
# 0      andaman-&-nicobar-islands  2018        1
# 1      andaman-&-nicobar-islands  2018        1
# 2      andaman-&-nicobar-islands  2018        1
# 3      andaman-&-nicobar-islands  2018        2
# 4      andaman-&-nicobar-islands  2018        2
# ...                          ...   ...      ...
# 16831                west-bengal  2023        3
# 16832                west-bengal  2023        3
# 16833                west-bengal  2023        3
# 16834                west-bengal  2023        3
# 16835                west-bengal  2023        3
#
#                                Districts  RegisteredUsers  AppOpens
# 0      north and middle andaman district              632         0
# 1                 south andaman district             5846         0
# 2                      nicobars district              262         0
# 3      north and middle andaman district              911         0
# ...

# %%
#top_transaction

path5="C:/Users/sujit/vs inside/Phonepe/pulse/data/top/transaction/country/india/state/"
top_tran_list=os.listdir(path5)

columns5={"States":[],"Years":[],"Quarter":[],"Pincodes":[],"Transaction_count":[],"Transaction_amount":[]}
for state in top_tran_list:
    cur_states = path5+state+"/"
    agg_year_list=os.listdir(cur_states)
    
    for year in agg_year_list:
        cur_year= cur_states+year+"/"
        agg_file_list = os.listdir(cur_year)
        
        for file in agg_file_list:
            cur_file = cur_year+file
            data=open(cur_file,"r")
            
            E=json.load(data)
            for i in E["data"]["pincodes"]:
                    name=i["entityName"]
                    count=i["metric"]["count"]
                    amount=i["metric"]["amount"]
                    columns5["Pincodes"].append(name)
                    columns5["Transaction_count"].append(count)
                    columns5["Transaction_amount"].append(amount)
                    columns5["States"].append(state)
                    columns5["Years"].append(year)
                    columns5["Quarter"].append(int(file.strip("j.son")))

# %%
top_trans=pd.DataFrame(columns5)

# %%
top_trans
# Out:
#                          States Years  Quarter Pincodes  Transaction_count  \
# 0     andaman-&-nicobar-islands  2018        1   744101               1622
# 1     andaman-&-nicobar-islands  2018        1   744103               1223
# 2     andaman-&-nicobar-islands  2018        1   744102                969
# 3     andaman-&-nicobar-islands  2018        1   744105                685
# 4     andaman-&-nicobar-islands  2018        1   744104                340
# ...                         ...   ...      ...      ...                ...
# 8205                west-bengal  2023        3   700001            3536928
# 8206                west-bengal  2023        3   721301            3464729
# 8207                west-bengal  2023        3   700039            3405551
# 8208                west-bengal  2023        3   732125            3347165
# 8209                west-bengal  2023        3   700015            3304464
#
#       Transaction_amount
# 0           2.769298e+06
# ...

# %%
#top_user

path6="C:/Users/sujit/vs inside/Phonepe/pulse/data/top/user/country/india/state/"
top_user_list=os.listdir(path6)

columns6={"States":[],"Years":[],"Quarter":[],"Pincodes":[],"RegisteredUsers":[]}
for state in top_user_list:
    cur_states = path6+state+"/"
    agg_year_list=os.listdir(cur_states)
    
    for year in agg_year_list:
        cur_year= cur_states+year+"/"
        agg_file_list = os.listdir(cur_year)
        
        for file in agg_file_list:
            cur_file = cur_year+file
            data=open(cur_file,"r")
            
            F=json.load(data)
            for i in F["data"]["pincodes"]:
                name=i["name"]
                registeredUsers=i["registeredUsers"]
                columns6["Pincodes"].append(name)
                columns6["RegisteredUsers"].append(registeredUsers)
                columns6["States"].append(state)
                columns6["Years"].append(year)
                columns6["Quarter"].append(int(file.strip("j.son")))

# %%
top_user = pd.DataFrame(columns6)

# %%
top_user
# Out:
#                          States Years  Quarter Pincodes  RegisteredUsers
# 0     andaman-&-nicobar-islands  2018        1   744103             1608
# 1     andaman-&-nicobar-islands  2018        1   744101             1108
# 2     andaman-&-nicobar-islands  2018        1   744105             1075
# 3     andaman-&-nicobar-islands  2018        1   744102             1006
# 4     andaman-&-nicobar-islands  2018        1   744104              272
# ...                         ...   ...      ...      ...              ...
# 8206                west-bengal  2023        3   700015           122316
# 8207                west-bengal  2023        3   742304           119245
# 8208                west-bengal  2023        3   721101           118798
# 8209                west-bengal  2023        3   700150           114987
# 8210                west-bengal  2023        3   734006           113991
#
# [8211 rows x 5 columns]

# %%
agg_tran.to_csv("aggre_transaction.csv",index=False)
aggre_user.to_csv("aggre_user.csv", index= False)
map_tran.to_csv("map_tran.csv",index = False)
map_user.to_csv("map_user.csv",index= False)
top_trans.to_csv("top_trans.csv",index=False)
top_user.to_csv("top_user.csv",index= False)

# %%
mydb = mysql.connector.connect(
                        host = "127.0.0.1",
                        user = "root",
                        password = "Sujithra@20",
                        database = "phonepe_pulse")
cursor=mydb.cursor()
mydb.commit()

# %%
#cursor.execute("CREATE DATABASE phonepe_pulse")

# %%
cursor.execute("create table agg_tran (State varchar(100), Year int, Quarter int, Transaction_type varchar(100), Transaction_count int, Transaction_amount double)")

for i,row in agg_tran.iterrows():
    #here %S means string values 
    sql = "INSERT INTO agg_tran VALUES (%s,%s,%s,%s,%s,%s)"
    cursor.execute(sql, tuple(row))
    # the connection is not auto committed by default, so we must commit to save our changes
    mydb.commit()

# %%
cursor.execute("create table agg_user (State varchar(100), Year int, Quarter int, Brands varchar(100), Transaction_count int, Percentage double)")

for i,row in aggre_user.iterrows():
    sql = "INSERT INTO agg_user VALUES (%s,%s,%s,%s,%s,%s)"
    cursor.execute(sql, tuple(row))
    mydb.commit()

# %%
cursor.execute("create table map_trans (State varchar(100), Year int, Quarter int, District varchar(100), Transaction_count int, Transaction_amount double)")

for i,row in map_tran.iterrows():
    sql = "INSERT INTO map_trans VALUES (%s,%s,%s,%s,%s,%s)"
    cursor.execute(sql, tuple(row))
    mydb.commit()

# %%
cursor.execute("create table if not exists map_user (State varchar(100), Year int, Quarter int, Districts varchar(100), RegisteredUsers int, AppOpens int)")

for i,row in map_user.iterrows():
    sql = "INSERT INTO map_user VALUES (%s,%s,%s,%s,%s,%s)"
    cursor.execute(sql, tuple(row))
    mydb.commit()

# %%
cursor.execute("create table if not exists top_trans (State varchar(100), Year int, Quarter int, Pincodes int, Transaction_count int, Transaction_amount double)")

for i,row in top_trans.iterrows():
    sql = "INSERT INTO top_trans VALUES (%s,%s,%s,%s,%s,%s)"
    cursor.execute(sql, tuple(row))
    mydb.commit()

# %%
cursor.execute("create table top_user (State varchar(100), Year int, Quarter int, Pincodes int, RegisteredUsers int)")

for i,row in top_user.iterrows():
    sql = "INSERT INTO top_user VALUES (%s,%s,%s,%s,%s)"
    cursor.execute(sql, tuple(row))
    mydb.commit()

# %%
cursor.execute("show tables")
cursor.fetchall()
# Out:
# [('agg_trans',),
#  ('agg_user',),
#  ('map_trans',),
#  ('map_user',),
#  ('top_trans',),
#  ('top_user',)]

# %%
"States":[],"Years":[],"Quarter":[],"Pincodes":[],"RegisteredUsers":[]}

# %%
mydb = mysql.connector.connect(
                        host = "127.0.0.1",
                        user = "root",
                        password = "Sujithra@20",
                        database = "phonepe_pulse")
cursor=mydb.cursor()
mydb.commit()
cursor.execute("SELECT * FROM phonepe_pulse.agg_trans")
myresult1 = cursor.fetchall()
at = pd.DataFrame(myresult1, columns=[ 'State', 'Year', 'Quarter', 'Transaction_type', 'Transaction_count', 'Transaction_amount'])

cursor.execute("SELECT * FROM phonepe_pulse.agg_user")
myresult2 = cursor.fetchall()
au = pd.DataFrame(myresult2, columns=[ 'State', 'Year', 'Quarter', 'Brands', 'Transaction_count', 'Percentage'])

cursor.execute("SELECT * FROM phonepe_pulse.map_trans")
myresult3 = cursor.fetchall()
mt = pd.DataFrame(myresult3, columns=[ 'State', 'Year', 'Quarter', 'District', 'Transaction_count', 'Transaction_amount'])

cursor.execute("SELECT * FROM phonepe_pulse.map_user")
myresult4 = cursor.fetchall()
mu = pd.DataFrame(myresult4, columns=[ 'State', 'Year', 'Quarter', 'Districts', 'RegisteredUsers','AppOpens'])

cursor.execute("SELECT * FROM phonepe_pulse.top_trans")
myresult5 = cursor.fetchall()
tt = pd.DataFrame(myresult5, columns=[ 'State', 'Year', 'Quarter', 'Pincode', 'Transaction_count', 'Transaction_amount'])

cursor.execute(("SELECT * FROM phonepe_pulse.top_user"))
myresult6 = cursor.fetchall()
tu = pd.DataFrame(myresult6, columns=['State', 'Year', 'Quarter', 'Pincodes', 'RegisteredUsers'])

mydb.close()

# %%
tu
# Out:
#                           State  Year  Quarter  Pincodes  RegisteredUsers
# 0     andaman-&-nicobar-islands  2018        1    744103             1608
# 1     andaman-&-nicobar-islands  2018        1    744101             1108
# 2     andaman-&-nicobar-islands  2018        1    744105             1075
# 3     andaman-&-nicobar-islands  2018        1    744102             1006
# 4     andaman-&-nicobar-islands  2018        1    744104              272
# ...                         ...   ...      ...       ...              ...
# 8206                west-bengal  2023        3    700015           122316
# 8207                west-bengal  2023        3    742304           119245
# 8208                west-bengal  2023        3    721101           118798
# 8209                west-bengal  2023        3    700150           114987
# 8210                west-bengal  2023        3    734006           113991
#
# [8211 rows x 5 columns]
